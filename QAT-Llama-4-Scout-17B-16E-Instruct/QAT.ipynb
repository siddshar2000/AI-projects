# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch

# %% [markdown]
# # Original size model doesn't even fit in memory.

# %%
# model='meta-llama/Llama-4-Scout-17B-16E-Instruct'
# AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model, device_map="auto")

# %% [markdown]
# ## Quantization

# %%
bnb_config = BitsAndBytesConfig(load_in_4bit=True)
model='meta-llama/Llama-4-Scout-17B-16E-Instruct'
qat_model = AutoModelForCausalLM.from_pretrained(model, quantization_config = bnb_config, device_map = 'auto')
# Out:
# None of the available devices `available_devices = None` are supported by the bitsandbytes version you have installed: `bnb_supported_devices = {'"cpu" (needs an Intel CPU and intel_extension_for_pytorch installed and compatible with the PyTorch version)', 'mps', 'hpu', 'cuda', 'npu', 'xpu'}`. Please check the docs to see if the backend you intend to use is available and how to install it: https://huggingface.co/docs/bitsandbytes/main/en/installation#multi-backend
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 3
#       1 bnb_config = BitsAndBytesConfig(load_in_4bit=True)
#       2 model='meta-llama/Llama-4-Scout-17B-16E-Instruct'
# ----> 3 qat_model = AutoModelForCausalLM.from_pretrained(model, quantization_config = bnb_config, device_map = 'auto')
#
# ...
